# 28.452237699999998 77.06653299999999 28.452173 77.0666955
# 28.452173 77.0666955 28.452108399999997 77.066858
# 28.452108399999997 77.066858 28.452043800000002 77.0670205
# 28.452043800000002 77.0670205 28.451979100000003 77.067183
# 28.451979100000003 77.067183 28.451914399999996 77.0673455
# 28.451914399999996 77.0673455 28.4518498 77.06750799999999
# 28.4518498 77.06750799999999 28.4517852 77.06767049999999
# 28.4517852 77.06767049999999 28.4517205 77.067833
# 28.4517205 77.067833 28.4516558 77.0679955
# 28.4516558 77.0679955 28.451591200000003 77.068158
# 28.451591200000003 77.068158 28.4515266 77.0683205
# 28.4515266 77.0683205 28.4514619 77.068483
# 28.4514619 77.068483 28.451397200000002 77.0686455
# 28.451397200000002 77.0686455 28.4513326 77.06880799999999
# 28.4513326 77.06880799999999 28.451268 77.06897049999999
# 28.451268 77.06897049999999 28.4512033 77.069133
# 28.4512033 77.069133 28.4511386 77.0692955

# %% [markdown]
# ## Printing time Format

# %%
i=0
for a,b in zip(df.Latitude, df.Longtitude):
    sec=i%60
    minn=int(i/60)
    sec2=(sec+1)%60
    minn2=minn+int((sec+1)/60)
    ttt=[sec,sec2,minn,minn2]
    tttx=[]
    for j in range(4):
        if(ttt[j]<9):
            tttx+=['0'+str(ttt[j])]
        else:
            tttx+=[str(ttt[j])]
    print(tttx)
    i+=1
# Out:
# ['00', '01', '00', '00']
# ['01', '02', '00', '00']
# ['02', '03', '00', '00']
# ['03', '04', '00', '00']
# ['04', '05', '00', '00']
# ['05', '06', '00', '00']
# ['06', '07', '00', '00']
# ['07', '08', '00', '00']
# ['08', '9', '00', '00']
# ['9', '10', '00', '00']
# ['10', '11', '00', '00']
# ['11', '12', '00', '00']
# ['12', '13', '00', '00']
# ['13', '14', '00', '00']
# ['14', '15', '00', '00']
# ['15', '16', '00', '00']
# ['16', '17', '00', '00']
# ['17', '18', '00', '00']
# ['18', '19', '00', '00']
# ['19', '20', '00', '00']
# ['20', '21', '00', '00']
# ['21', '22', '00', '00']
# ['22', '23', '00', '00']
# ['23', '24', '00', '00']
# ['24', '25', '00', '00']
# ['25', '26', '00', '00']
# ['26', '27', '00', '00']
# ['27', '28', '00', '00']
# ['28', '29', '00', '00']
# ['29', '30', '00', '00']
# ['30', '31', '00', '00']
# ['31', '32', '00', '00']
# ['32', '33', '00', '00']
# ['33', '34', '00', '00']
# ['34', '35', '00', '00']
# ['35', '36', '00', '00']
# ['36', '37', '00', '00']
# ['37', '38', '00', '00']
# ['38', '39', '00', '00']
# ['39', '40', '00', '00']
# ['40', '41', '00', '00']
# ['41', '42', '00', '00']
# ['42', '43', '00', '00']
# ['43', '44', '00', '00']
# ['44', '45', '00', '00']
# ['45', '46', '00', '00']
# ['46', '47', '00', '00']
# ['47', '48', '00', '00']
# ['48', '49', '00', '00']
# ['49', '50', '00', '00']
# ['50', '51', '00', '00']
# ['51', '52', '00', '00']
# ['52', '53', '00', '00']
# ['53', '54', '00', '00']
# ['54', '55', '00', '00']
# ['55', '56', '00', '00']
# ['56', '57', '00', '00']
# ['57', '58', '00', '00']
# ['58', '59', '00', '00']
# ['59', '00', '00', '01']
# ['00', '01', '01', '01']
# ['01', '02', '01', '01']
# ['02', '03', '01', '01']
# ['03', '04', '01', '01']
# ['04', '05', '01', '01']
# ['05', '06', '01', '01']
# ['06', '07', '01', '01']
# ['07', '08', '01', '01']
# ['08', '9', '01', '01']
# ['9', '10', '01', '01']
# ['10', '11', '01', '01']
# ['11', '12', '01', '01']
# ['12', '13', '01', '01']
# ['13', '14', '01', '01']
# ['14', '15', '01', '01']
# ['15', '16', '01', '01']
# ['16', '17', '01', '01']
# ['17', '18', '01', '01']
# ['18', '19', '01', '01']
# ['19', '20', '01', '01']
# ['20', '21', '01', '01']
# ['21', '22', '01', '01']
# ['22', '23', '01', '01']
# ['23', '24', '01', '01']
# ['24', '25', '01', '01']
# ['25', '26', '01', '01']
# ['26', '27', '01', '01']
# ['27', '28', '01', '01']
# ['28', '29', '01', '01']
# ['29', '30', '01', '01']
# ['30', '31', '01', '01']
# ['31', '32', '01', '01']
# ['32', '33', '01', '01']
# ['33', '34', '01', '01']
# ['34', '35', '01', '01']
# ['35', '36', '01', '01']
# ['36', '37', '01', '01']
# ['37', '38', '01', '01']
# ['38', '39', '01', '01']
# ['39', '40', '01', '01']

# %% [markdown]
# ## Addition 1 My LOC

# %%
c=77.0697872
d=28.450810200000003
i=0
j=0
lines=[]
for a,b in zip(df.Latitude, df.Longtitude):
    sec=i%60
    minn=int(i/60)
    sec2=(sec+1)%60
    minn2=minn+int((sec+1)/60)
    ttt=[sec,sec2,minn,minn2]
    tttx=[]
    for j in range(4):
        if(ttt[j]<=9):
            tttx+=['0'+str(ttt[j])]
        else:
            tttx+=[str(ttt[j])]
            
    lines+= [
        {
            'coordinates': [
                [c, d],
                [b, a],
            ],
            'dates': [
                '2019-03-11T'+tttx[2]+":"+tttx[0]+":00",
                '2019-03-11T'+tttx[3]+":"+tttx[1]+":00"
#                 '2019-03-11T'+"00"+":"+tttx[0]+":00",
#                 '2019-03-11T'+"00"+":"+tttx[1]+":00"
            ],
            'color': 'red'
        },
    ]
    c=b
    d=a
    i=i+1
lines=lines[1:]

# %% [markdown]
# ## 2nd Addition

# %%
c=77.0697872
d=28.450810200000003
i=0
j=0
lines2=[]
for a,b in zip(df2.Latitude, df2.Longtitude):
    sec=i%60
    minn=int(i/60)
    sec2=(sec+1)%60
    minn2=minn+int((sec+1)/60)
    ttt=[sec,sec2,minn,minn2]
    tttx=[]
    for j in range(4):
        if(ttt[j]<=9):
            tttx+=['0'+str(ttt[j])]
        else:
            tttx+=[str(ttt[j])]
            
    lines2+= [
        {
            'coordinates': [
                [c, d],
                [b, a],
            ],
            'dates': [
                '2019-03-11T'+tttx[2]+":"+tttx[0]+":00",
                '2019-03-11T'+tttx[3]+":"+tttx[1]+":00"
#                 '2019-03-11T'+"00"+":"+tttx[0]+":00",
#                 '2019-03-11T'+"00"+":"+tttx[1]+":00"
            ],
            'color': 'blue'
        },
    ]
    c=b
    d=a
    i=i+1
lines2=lines2[1:]

# %%
features = [
    {
        'type': 'Feature',
        'geometry': {
            'type': 'LineString',
            'coordinates': line['coordinates'],
        },
        'properties': {
            'times': line['dates'],
            'style': {
                'color': line['color'],
                'weight': line['weight'] if 'weight' in line else 3
            }
        }
    }
    for line in lines+lines2
]

q = folium.Map(
    location=[28.3893239,77.0551068],
    zoom_start=16
)

plugins.TimestampedGeoJson({
    'type': 'FeatureCollection',
    'features': features,
}, period='PT1M', add_last_point=False).add_to(q)
q
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
features
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0697872, 28.450810200000003],
#     [77.0555867, 28.389777000000002]]},
#   'properties': {'times': ['2019-03-11T00:00:00', '2019-03-11T00:00:01'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0555867, 28.389777000000002],
#     [77.0555558, 28.3897777]]},
#   'properties': {'times': ['2019-03-11T00:00:01', '2019-03-11T00:00:02'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0555558, 28.3897777], [77.055525, 28.389778399999997]]},
#   'properties': {'times': ['2019-03-11T00:00:02', '2019-03-11T00:00:03'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.055525, 28.389778399999997],
#     [77.0554941, 28.389779100000002]]},
#   'properties': {'times': ['2019-03-11T00:00:03', '2019-03-11T00:00:04'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0554941, 28.389779100000002],
#     [77.05546329999999, 28.3897799]]},
#   'properties': {'times': ['2019-03-11T00:00:04', '2019-03-11T00:00:05'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.05546329999999, 28.3897799],
#     [77.0554324, 28.389780600000005]]},
#   'properties': {'times': ['2019-03-11T00:00:05', '2019-03-11T00:00:06'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0554324, 28.389780600000005],
#     [77.0554016, 28.389781300000003]]},
#   'properties': {'times': ['2019-03-11T00:00:06', '2019-03-11T00:00:07'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0554016, 28.389781300000003],
#     [77.05537070000001, 28.389782]]},
#   'properties': {'times': ['2019-03-11T00:00:07', '2019-03-11T00:00:08'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.05537070000001, 28.389782], [77.0553399, 28.3897828]]},
#   'properties': {'times': ['2019-03-11T00:00:08', '2019-03-11T00:00:9'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0553399, 28.3897828], [77.055309, 28.389783500000004]]},
#   'properties': {'times': ['2019-03-11T00:00:9', '2019-03-11T00:00:10'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.055309, 28.389783500000004], [77.0552782, 28.3897842]]},
#   'properties': {'times': ['2019-03-11T00:00:10', '2019-03-11T00:00:11'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0552782, 28.3897842], [77.0552473, 28.3897849]]},
#   'properties': {'times': ['2019-03-11T00:00:11', '2019-03-11T00:00:12'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0552473, 28.3897849],
#     [77.0552165, 28.389785600000003]]},
#   'properties': {'times': ['2019-03-11T00:00:12', '2019-03-11T00:00:13'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0552165, 28.389785600000003],
#     [77.05518559999999, 28.3897864]]},
#   'properties': {'times': ['2019-03-11T00:00:13', '2019-03-11T00:00:14'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.05518559999999, 28.3897864],
#     [77.0551548, 28.389787100000003]]},
#   'properties': {'times': ['2019-03-11T00:00:14', '2019-03-11T00:00:15'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.
],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0701163, 28.4505463],
#     [77.0697872, 28.450810200000003]]},
#   'properties': {'times': ['2019-03-11T00:01:39', '2019-03-11T00:01:40'],
#    'style': {'color': 'red', 'weight': 5}}}]

# %%
features
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.05558665545016, 28.389776984249156],
#     [77.0549697, 28.3897914]]},
#   'properties': {'times': ['2019-03-11T00:00:00', '2019-03-11T00:10:00'],
#    'style': {'color': 'red', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.0549697, 28.3897914], [77.065865, 28.394027]]},
#   'properties': {'times': ['2019-03-11T00:10:00', '2019-03-11T00:20:00'],
#    'style': {'color': 'blue', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.065865, 28.394027], [77.051921, 28.421017]]},
#   'properties': {'times': ['2019-03-11T00:25:00', '2019-03-11T00:30:00'],
#    'style': {'color': 'blue', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.051921, 28.421017], [77.076041, 28.445797]]},
#   'properties': {'times': ['2019-03-11T00:30:00', '2019-03-11T00:45:00'],
#    'style': {'color': 'blue', 'weight': 5}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[77.076041, 28.445797], [77.069458, 28.451074]]},
#   'properties': {'times': ['2019-03-11T00:45:00', '2019-03-11T00:57:00'],
#    'style': {'color': 'blue', 'weight': 5}}}]

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[28.3893239,77.0551068],
    zoom_start=16
)


# Lon, Lat order.
lines = [

    {   
        'coordinates': [
            [77.05558665545016, 28.389776984249156],
            [77.0549697, 28.3897914],
        ],
        'dates': [
            '2019-03-11T00:00:00',
            '2019-03-11T00:10:00'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [77.0549697, 28.3897914],
            [77.065865,28.394027],
        ],
        'dates': [
             '2019-03-11T00:10:00',
            '2019-03-11T00:20:00'
        ],
        'color': 'blue'
    },
    {
        'coordinates': [
            [77.065865,28.394027],
            [77.051921,28.421017],
        ],
        'dates': [
            '2019-03-11T00:25:00',
            '2019-03-11T00:30:00'
        ],
        'color': 'blue',
    },
    {
        'coordinates': [
            [77.051921,28.421017],
            [77.076041,28.445797],
        ],
        'dates': [
            '2019-03-11T00:30:00',
            '2019-03-11T00:45:00'
        ],
        'color': 'blue',
    },
{
        'coordinates': [
            [77.076041,28.445797],
            [77.069458,28.451074],
        ],
        'dates': [
            '2019-03-11T00:45:00',
            '2019-03-11T00:57:00'
        ],
        'color': 'blue',
    },
]

features = [
    {
        'type': 'Feature',
        'geometry': {
            'type': 'LineString',
            'coordinates': line['coordinates'],
        },
        'properties': {
            'times': line['dates'],
            'style': {
                'color': line['color'],
                'weight': line['weight'] if 'weight' in line else 5
            }
        }
    }
    for line in lines
]

plugins.TimestampedGeoJson({
    'type': 'FeatureCollection',
    'features': features,
}, period='PT1M', add_last_point=True).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import datetime
day_delta = datetime.timedelta(days=1)

start_date = datetime.date.today()
end_date = start_date + 7*day_delta

for i in range((end_date - start_date).days):
    print(start_date + i*day_delta)
# Out:
# 2020-04-06
# 2020-04-07
# 2020-04-08
# 2020-04-09
# 2020-04-10
# 2020-04-11
# 2020-04-12
