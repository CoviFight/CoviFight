# %%
# !pip install googlemaps
# Out:
# ...
#   Using cached googlemaps-4.2.0-py3-none-any.whl (38 kB)
# ...
#   Using cached requests-2.23.0-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached idna-2.9-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached urllib3-1.25.8-py2.py3-none-any.whl (125 kB)
# ...
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# ...

# %%
import googlemaps
import json
import pprint
#import xlsxwriter
import time

# %%
# Define the API Key.
API_KEY = 'AIzaSyAwNhcSsvvWOPIVW8ZHgMVumWwvdIbFJfM'

# Define the Client
gmaps = googlemaps.Client(key = API_KEY)

# %%
arr=[]

# %%
places_result  = gmaps.places_nearby(location='28.38, 77.05', radius = 10000, open_now =False , type = 'park')

# %%
x=0
for i in range(0,5,1):#5
    for j in range(0,9,1):#9
        print("**********************blank loop*******************************")
        lat=28.17+i*.1#.1
        long=76.63+j*.1#.1
        time.sleep(3)
        try:
            places_result = gmaps.places_nearby(location=str(lat)+", "+str(long), 
                                                radius = 10000,#10000 
                                                open_now =False , 
                                                type = 'store')
        except:
            print("error")
            break
        
        for k in range(2):
            print("-------------------",len(places_result['results']),"------------------------------------")
            for l in range(len(places_result['results'])):
                data=list(places_result['results'][l]['geometry']['location'].values())
                data=[places_result['results'][l]['name']]+data
                print(x," ",places_result['results'][l]['name']," ",data)
                arr+=[data]
                x+=1
            if(len(places_result['results'])<20):
                break
            time.sleep(3)
            try:
                places_result = gmaps.places_nearby(page_token = places_result['next_page_token'])
            except:
                print("error")
                break
# Out:
# **********************blank loop*******************************
# ------------------- 20 ------------------------------------
# 0   Sonu Gift Palace & Studio   ['Sonu Gift Palace & Studio', 28.1881704, 76.6171565]
# 1   P. G. Goyal Industries   ['P. G. Goyal Industries', 28.2045144, 76.6557102]
# 2   Amazed Planet Software Training   ['Amazed Planet Software Training', 28.19033, 76.61286419999999]
# 3   Reliance Smart   ['Reliance Smart', 28.1947069, 76.62111689999999]
# 4   Mohit Pickle Factory   ['Mohit Pickle Factory', 28.1713533, 76.6257653]
# 5   The Veggi Store   ['The Veggi Store', 28.17689559999999, 76.61551550000001]
# 6   Shivam Sun Solar System   ['Shivam Sun Solar System', 28.18199799999999, 76.618899]
# 7   Store   ['Store', 28.1806985, 76.61713739999999]
# 8   Rustagi General Store Niiku Ki Dukan   ['Rustagi General Store Niiku Ki Dukan', 28.1810057, 76.6172539]
# 9   Parshant Store   ['Parshant Store', 28.1810988, 76.6167698]
# ...

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-1.0.3-cp37-cp37m-win_amd64.whl (8.7 MB)
# ...
#   Using cached pytz-2019.3-py2.py3-none-any.whl (509 kB)
# ...
#   Using cached numpy-1.18.2-cp37-cp37m-win_amd64.whl (12.8 MB)
# ...

# %%
import pandas as pd

# %%
data=pd.DataFrame(arr)

# %%
data
# Out:
#                                                       0          1          2
# 0                             Sonu Gift Palace & Studio  28.188170  76.617156
# 1                                P. G. Goyal Industries  28.204514  76.655710
# 2                       Amazed Planet Software Training  28.190330  76.612864
# 3                                        Reliance Smart  28.194707  76.621117
# 4                                  Mohit Pickle Factory  28.171353  76.625765
# ...                                                 ...        ...        ...
# 1015                       Mecpro Heavy Engineering Ltd  28.567892  77.187390
# 1016                     PMS Engineering (Intl) Service  28.555003  77.177252
# 1017                     A.s. Electronics & Electricals  28.556821  77.165457
# 1018                  Agility Logistics Private Limited  28.544564  77.113924
# 1019  NEW VISHAWAKARMA INDUSTRIES | Car Audio Wiring...  28.618378  77.113514
#
# [746 rows x 3 columns]

# %%
data.drop_duplicates(subset =[0,1,2], keep = "first", inplace = True)

# %%
data.to_csv("store.csv")

# %%
len(places_result['results'])
# Out:
# 20

# %%
for i in range(20):
  print(places_result['results'][i]['name'])
# Out:
# Pugdundee Safaris
# Horticulture Services Gurgaon
# Farm Park Aklimpur
# Ashok Vatika Aklimpur
# Banyan Tree Aklimpur
# Park
# Park
# E-Space Park
# Park
# Park
# G Block Park
# Park
# A-Block Park
# Deerwood Chase Nirvana Country Gurgaon
# B-Block Park
# Park
# I Block Park
# Colony Ground
# M2K Aura Common Park
# Subedar Ram Narain Trance
